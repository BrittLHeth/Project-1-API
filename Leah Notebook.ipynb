# %%
import requests
import json
import pandas as pd

# %%
health_data_path= "Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System (version 1).csv"
health_data = pd.read_csv(health_data_path)
health_data.head()
# Out:
#    eek, an  YearEnd LocationAbbr LocationDesc  \
# 0     2011     2011           AK       Alaska
# 1     2011     2011           AK       Alaska
# 2     2011     2011           AK       Alaska
# 3     2011     2011           AK       Alaska
# 4     2011     2011           AK       Alaska
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 2  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 3  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 4  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
#
#    Data_Value_Unit Data_Value_Type  ...                        GeoLocation  \
# 0              NaN           Value  ...  (64.845079957001, -147.722059036)
# 1              NaN           Value  ...  (64.845079957001, -147.722059036)
# 2              NaN           Value  ...  (64.845079957001, -147.722059036)
# 3              NaN           Value  ...  (64.845079957001, -147.722059036)
# 4              NaN           Value  ...  (64.845079957001, -147.722059036)
#
#    ClassID TopicID QuestionID  DataValueTypeID  LocationID  \
# 0      OWS    OWS1       Q037            VALUE           2
# 1      OWS    OWS1       Q037            VALUE           2
# 2      OWS    OWS1       Q037            VALUE           2
# 3      OWS    OWS1       Q037            VALUE           2
# 4      OWS    OWS1       Q037            VALUE           2
#
#    StratificationCategory1    Stratification1 StratificationCategoryId1  \
# 0                   Income  $15,000 - $24,999                       INC
# 1              Age (years)            35 - 44                     AGEYR
# 2                   Income  Less than $15,000                       INC
# 3                   Income  $35,000 - $49,999                       INC
# 4           Race/Ethnicity           Hispanic                      RACE
#
#   StratificationID1
# 0           INC1525
# 1         AGEYR3544
# 2         INCLESS15
# 3           INC3550
# 4           RACEHIS
#
# [5 rows x 33 columns]

# %%
clean_health_data = pd.DataFrame(health_data[["YearEnd","LocationDesc","Question","Data_Value"]])

final_health_data = clean_health_data.loc[clean_health_data.YearEnd == 2017]

final_health_data.head()
# Out:
#       YearEnd LocationDesc                                           Question  \
# 8960     2017       Alaska  Percent of adults aged 18 years and older who ...
# 8961     2017       Alaska  Percent of adults aged 18 years and older who ...
# 8962     2017       Alaska  Percent of adults aged 18 years and older who ...
# 8963     2017       Alaska  Percent of adults aged 18 years and older who ...
# 8964     2017       Alaska  Percent of adults aged 18 years and older who ...
#
#       Data_Value
# 8960         NaN
# 8961        34.3
# 8962        27.5
# 8963        31.4
# 8964         NaN

# %%
final_health_data.groupby(["Question", "LocationDesc"]).agg({"Data_Value": ["mean", "median", "var", "std", "sem"]})
# Out:
#                                                                  Data_Value  \
#                                                                        mean
# Question                                           LocationDesc
# Percent of adults aged 18 years and older who h... Alabama        33.792000
#                                                    Alaska         31.858333
#                                                    Arizona        34.707407
#                                                    Arkansas       36.272000
#                                                    California     35.670370
# ...                                                                     ...
# Percent of adults who report consuming vegetabl... Virginia       17.003846
#                                                    Washington     18.748148
#                                                    West Virginia  18.804348
#                                                    Wisconsin      20.469231
#                                                    Wyoming        16.745833
#
#                                                                          \
#                                                                  median
# Question                                           LocationDesc
# Percent of adults aged 18 years and older who h... Alabama        33.30
#                                                    Alaska         32.15
#                                                    Arizona        35.30
#                                                    Arkansas       36.20
#                                                    California     36.70
# ...                                                                 ...
# Percent of adults who report consuming vegetabl... Virginia       15.75
#                                                    Washington     16.70
#                                                    West Virginia  19.70
#                                                    Wisconsin      19.45
#                                                    Wyoming        14.85
#
#                                                                              \
#                                                                         var
# Question                                           LocationDesc
# Percent of adults aged 18 years and older who h... Alabama        13.667433
#                                                    Alaska         12.642536
#                                                    Arizona        12.994558
#                                                    Arkansas       31.933767
#                                                    California     18.642165
# ...                                                                     ...
# Percent of adults who report consuming vegetabl... Virginia       31.140385
#                                                    Washington     40.192593
#                                                    West Virginia  25.374980
#                                                    Wisconsin      24.936615
#                                                    Wyoming        23.454764
#
#                                                                             \
#                                                                        std
# Question                                           LocationDesc
# Percent of adults aged 18 years and older who h... Alabama        3.696949
#                                                    Alaska         3.555634
#                                                    Arizona        3.604797
#                                                    Arkansas       5.650997
#                                                    California     4.317657
# ...                                                                    ...
# Percent of adults who report consuming vegetabl... Virginia       5.580357
#                                                    Washington     6.339763
#                                                    West Virginia  5.037358
#                                                    Wisconsin      4.993658
#                                                    Wyoming        4.843012
#
#
#                                                                        sem
# Question                                           LocationDesc
# Percent of adults aged 18 years and older who h... Alabama        0.739390
#                                                    Alaska         0.725791
#                                                    Arizona        0.693743
#                                                    Arkansas       1.130199
#                                                    California     0.830934
# ...                                                                    ...
# Percent of adults who report consuming vegetabl... Virginia       1.094398
#                                                    Washington     1.220088
#                                                    West Virginia  1.050362
#                                                    Wisconsin      0.979337
#                                                    Wyoming        0.988576
#
# [495 rows x 5 columns]

# %%
url = "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=42602&bdate=20170101&edate=20171231&state=37"

# %%
response = requests.get(url)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "Data": [
#         {
#             "arithmetic_mean": 6.28245,
#             "cbsa": "Charlotte-Concord-Gastonia, NC-SC",
#             "cbsa_code": "16740",
#             "certification_indicator": "Certified",
#             "city": "Charlotte",
#             "county": "Mecklenburg",
#             "county_code": "119",
#             "date_of_last_change": "2019-03-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 4.2,
#             "first_max_datetime": "2018-01-09 18:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 39.6,
#             "fourth_max_datetime": "2018-01-08 18:00",
#             "fourth_max_value": 37.9,
#             "latitude": 35.2401,
#             "local_site_name": "Garinger High School",
#             "longitude": -80.785683,
#             "method": "INSTRUMENTAL - CHEMILUMINESCENCE",
#             "metric_used": "Observed values",
#             "ninetieth_percentile": 13.6,
#             "ninety_eighth_percentile": 27.0,
#             "ninety_fifth_percentile": 19.0,
#             "ninety_ninth_percentile": 29.8,
#             "null_observation_count": 1666,
#             "observation_count": 7094,
#             "observation_percent": 81.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 Annual 1971",
#             "primary_exceedance_count": null,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-01-08 17:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 38.5,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 7.8,
#             "site_address": "1130 EASTWAY DRIVE",
#             "site_number": "0041",
#             "standard_deviation": 5.950497,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 1.7,
#             "third_max_datetime": "2018-01-09 19:00",
#             "third_max_value": 38.0,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 303,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 14.092409,
#             "cbsa": "Charlotte-Concord-Gastonia, NC-SC",
#             "cbsa_code": "16740",
#             "certification_indicator": "Certified",
#             "city": "Charlotte",
#             "county": "Mecklenburg",
#             "county_code": "119",
#             "date_of_last_change": "2019-03-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 12.3,
#             "first_max_datetime": "2018-01-09 18:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 39.6,
#             "fourth_max_datetime": "2018-01-26 07:00",
#             "fourth_max_value": 37.3,
#             "latitude": 35.2401,
#             "local_site_name": "Garinger High School",
#             "longitude": -80.785683,
#             "method": "INSTRUMENTAL - CHEMILUMINESCENCE",
#             "metric_used": "Daily Maximum 1-hour average",
#             "ninetieth_percentile": 28.2,
#             "ninety_eighth_percentile": 35.8,
#             "ninety_fifth_percentile": 31.6,
#             "ninety_ninth_percentile": 37.3,
#             "null_observation_count": 1666,
#             "observation_count": 7094,
#             "observation_percent": 81.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 1-hour",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-01-08 17:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 38.5,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 18.0,
#             "site_address": "1130 EASTWAY DRIVE",
#             "site_number": "0041",
#             "standard_deviation": 8.470399,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 5.4,
#             "third_max_datetime": "2018-01-05 06:00",
#             "third_max_value": 37.3,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 303,
#             "validity_indicator": "N",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 10.198556,
#             "cbsa": "Charlotte-Concord-Gastonia, NC-SC",
#             "cbsa_code": "16740",
#             "certification_indicator": "Certified",
#             "city": "Charlotte",
#             "county": "Mecklenburg",
#             "county_code": "119",
#             "date_of_last_change": "2019-01-23",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 8.7,
#             "first_max_datetime": "2018-03-16 20:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 39.2,
#             "fourth_max_datetime": "2018-03-05 20:00",
#             "fourth_max_value": 36.9,
#             "latitude": 35.213171,
#             "local_site_name": "Remount",
#             "longitude": -80.874084,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Observed values",
#             "ninetieth_percentile": 19.9,
#             "ninety_eighth_percentile": 27.4,
#             "ninety_fifth_percentile": 23.7,
#             "ninety_ninth_percentile": 29.9,
#             "null_observation_count": 728,
#             "observation_count": 8032,
#             "observation_percent": 92.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 Annual 1971",
#             "primary_exceedance_count": null,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-01-26 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 38.3,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 13.8,
#             "site_address": "1030 Remount Road",
#             "site_number": "0045",
#             "standard_deviation": 6.712122,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 2.9,
#             "third_max_datetime": "2018-01-03 04:00",
#             "third_max_value": 37.1,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 340,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 19.919706,
#             "cbsa": "Charlotte-Concord-Gastonia, NC-SC",
#             "cbsa_code": "16740",
#             "certification_indicator": "Certified",
#             "city": "Charlotte",
#             "county": "Mecklenburg",
#             "county_code": "119",
#             "date_of_last_change": "2019-01-23",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 19.5,
#             "first_max_datetime": "2018-03-16 20:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 39.2,
#             "fourth_max_datetime": "2018-03-05 20:00",
#             "fourth_max_value": 36.9,
#             "latitude": 35.213171,
#             "local_site_name": "Remount",
#             "longitude": -80.874084,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Daily Maximum 1-hour average",
#             "ninetieth_percentile": 30.4,
#             "ninety_eighth_percentile": 34.9,
#             "ninety_fifth_percentile": 32.5,
#             "ninety_ninth_percentile": 36.9,
#             "null_observation_count": 728,
#             "observation_count": 8032,
#             "observation_percent": 92.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 1-hour",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-01-26 09:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 38.3,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 25.0,
#             "site_address": "1030 Remount Road",
#             "site_number": "0045",
#             "standard_deviation": 7.141213,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 11.1,
#             "third_max_datetime": "2018-01-03 04:00",
#             "third_max_value": 37.1,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 340,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 4.955026,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certified",
#             "city": "Raleigh",
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2019-06-24",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 3.1,
#             "first_max_datetime": "2018-01-19 19:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 38.2,
#             "fourth_max_datetime": "2018-01-19 18:00",
#             "fourth_max_value": 35.7,
#             "latitude": 35.856111,
#             "local_site_name": "Millbrook School",
#             "longitude": -78.574167,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Observed values",
#             "ninetieth_percentile": 11.3,
#             "ninety_eighth_percentile": 23.4,
#             "ninety_fifth_percentile": 17.0,
#             "ninety_ninth_percentile": 27.6,
#             "null_observation_count": 847,
#             "observation_count": 7889,
#             "observation_percent": 90.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 Annual 1971",
#             "primary_exceedance_count": null,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-01-19 20:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 38.2,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 5.8,
#             "site_address": "3801 SPRING FOREST RD.",
#             "site_number": "0014",
#             "standard_deviation": 5.435052,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 1.0,
#             "third_max_datetime": "2018-04-30 20:00",
#             "third_max_value": 35.8,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 342,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 12.617251,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certified",
#             "city": "Raleigh",
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2019-06-24",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 10.3,
#             "first_max_datetime": "2018-01-19 19:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 38.2,
#             "fourth_max_datetime": "2018-01-20 19:00",
#             "fourth_max_value": 35.1,
#             "latitude": 35.856111,
#             "local_site_name": "Millbrook School",
#             "longitude": -78.574167,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Daily Maximum 1-hour average",
#             "ninetieth_percentile": 25.4,
#             "ninety_eighth_percentile": 34.2,
#             "ninety_fifth_percentile": 30.2,
#             "ninety_ninth_percentile": 35.1,
#             "null_observation_count": 847,
#             "observation_count": 7889,
#             "observation_percent": 90.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 1-hour",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-04-30 20:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 35.8,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 17.8,
#             "site_address": "3801 SPRING FOREST RD.",
#             "site_number": "0014",
#             "standard_deviation": 8.301109,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 3.9,
#             "third_max_datetime": "2018-10-04 20:00",
#             "third_max_value": 35.7,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 342,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 1.047533,
#             "cbsa": "Sanford, NC",
#             "cbsa_code": "41820",
#             "certification_indicator": "Certified",
#             "city": "Sanford",
#             "county": "Lee",
#             "county_code": "105",
#             "date_of_last_change": "2019-06-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.8,
#             "first_max_datetime": "2018-01-03 08:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 7.7,
#             "fourth_max_datetime": "2018-01-11 08:00",
#             "fourth_max_value": 6.8,
#             "latitude": 35.4325,
#             "local_site_name": "Blackstone",
#             "longitude": -79.2887,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Observed values",
#             "ninetieth_percentile": 2.1,
#             "ninety_eighth_percentile": 3.6,
#             "ninety_fifth_percentile": 2.8,
#             "ninety_ninth_percentile": 4.2,
#             "null_observation_count": 460,
#             "observation_count": 4641,
#             "observation_percent": 53.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 Annual 1971",
#             "primary_exceedance_count": null,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-02-28 03:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 7.6,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.4,
#             "site_address": "4110 Blackstone Drive",
#             "site_number": "0002",
#             "standard_deviation": 0.876343,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.2,
#             "third_max_datetime": "2018-01-03 09:00",
#             "third_max_value": 7.5,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 201,
#             "validity_indicator": "N",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 2.431841,
#             "cbsa": "Sanford, NC",
#             "cbsa_code": "41820",
#             "certification_indicator": "Certified",
#             "city": "Sanford",
#             "county": "Lee",
#             "county_code": "105",
#             "date_of_last_change": "2019-06-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 2.1,
#             "first_max_datetime": "2018-01-03 08:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 7.7,
#             "fourth_max_datetime": "2018-01-15 19:00",
#             "fourth_max_value": 6.1,
#             "latitude": 35.4325,
#             "local_site_name": "Blackstone",
#             "longitude": -79.2887,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Daily Maximum 1-hour average",
#             "ninetieth_percentile": 4.3,
#             "ninety_eighth_percentile": 6.1,
#             "ninety_fifth_percentile": 4.8,
#             "ninety_ninth_percentile": 6.8,
#             "null_observation_count": 460,
#             "observation_count": 4641,
#             "observation_percent": 53.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 1-hour",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-02-28 03:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 7.6,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 3.1,
#             "site_address": "4110 Blackstone Drive",
#             "site_number": "0002",
#             "standard_deviation": 1.350289,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 1.1,
#             "third_max_datetime": "2018-01-11 08:00",
#             "third_max_value": 6.8,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 201,
#             "validity_indicator": "N",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 6.652983,
#             "cbsa": "Winston-Salem, NC",
#             "cbsa_code": "49180",
#             "certification_indicator": "Certified",
#             "city": "Winston-Salem",
#             "county": "Forsyth",
#             "county_code": "067",
#             "date_of_last_change": "2019-04-18",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 4.7,
#             "first_max_datetime": "2018-12-11 18:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 41.0,
#             "fourth_max_datetime": "2018-12-12 21:00",
#             "fourth_max_value": 39.7,
#             "latitude": 36.110693,
#             "local_site_name": "Hattie Avenue",
#             "longitude": -80.226438,
#             "method": "Instrumental - Chemiluminescence Teledyne API 200 EU/501",
#             "metric_used": "Observed values",
#             "ninetieth_percentile": 14.1,
#             "ninety_eighth_percentile": 25.5,
#             "ninety_fifth_percentile": 19.0,
#             "ninety_ninth_percentile": 29.1,
#             "null_observation_count": 512,
#             "observation_count": 8248,
#             "observation_percent": 94.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 Annual 1971",
#             "primary_exceedance_count": null,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-12-12 19:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 39.8,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 8.3,
#             "site_address": "1300 BLK. HATTIE AVENUE",
#             "site_number": "0022",
#             "standard_deviation": 5.779044,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 2.0,
#             "third_max_datetime": "2018-12-11 19:00",
#             "third_max_value": 39.7,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 358,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 14.696648,
#             "cbsa": "Winston-Salem, NC",
#             "cbsa_code": "49180",
#             "certification_indicator": "Certified",
#             "city": "Winston-Salem",
#             "county": "Forsyth",
#             "county_code": "067",
#             "date_of_last_change": "2019-04-18",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 12.8,
#             "first_max_datetime": "2018-12-11 18:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 41.0,
#             "fourth_max_datetime": "2018-01-02 19:00",
#             "fourth_max_value": 37.2,
#             "latitude": 36.110693,
#             "local_site_name": "Hattie Avenue",
#             "longitude": -80.226438,
#             "method": "Instrumental - Chemiluminescence Teledyne API 200 EU/501",
#             "metric_used": "Daily Maximum 1-hour average",
#             "ninetieth_percentile": 26.6,
#             "ninety_eighth_percentile": 35.3,
#             "ninety_fifth_percentile": 30.0,
#             "ninety_ninth_percentile": 37.2,
#             "null_observation_count": 512,
#             "observation_count": 8248,
#             "observation_percent": 94.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 1-hour",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-12-12 19:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 39.8,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 19.2,
#             "site_address": "1300 BLK. HATTIE AVENUE",
#             "site_number": "0022",
#             "standard_deviation": 7.90687,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 6.1,
#             "third_max_datetime": "2018-12-13 00:00",
#             "third_max_value": 38.0,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 358,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 8.700441,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2019-06-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 7.6,
#             "first_max_datetime": "2018-03-16 04:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 35.0,
#             "fourth_max_datetime": "2018-04-06 20:00",
#             "fourth_max_value": 33.9,
#             "latitude": 35.8652,
#             "local_site_name": "Triple Oak",
#             "longitude": -78.8197,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Observed values",
#             "ninetieth_percentile": 16.2,
#             "ninety_eighth_percentile": 24.1,
#             "ninety_fifth_percentile": 19.8,
#             "ninety_ninth_percentile": 26.7,
#             "null_observation_count": 794,
#             "observation_count": 7942,
#             "observation_percent": 91.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 Annual 1971",
#             "primary_exceedance_count": null,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-03-09 22:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 34.3,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 11.8,
#             "site_address": "2826 TRIPLE OAK DRIVE",
#             "site_number": "0021",
#             "standard_deviation": 5.677581,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 2.5,
#             "third_max_datetime": "2018-03-16 06:00",
#             "third_max_value": 34.3,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 343,
#             "validity_indicator": "Y",
#             "year": 2018
#         },
#         {
#             "arithmetic_mean": 16.432653,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certified",
#             "city": null,
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2019-06-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 15.6,
#             "first_max_datetime": "2018-03-16 04:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 35.0,
#             "fourth_max_datetime": "2018-02-27 20:00",
#             "fourth_max_value": 33.8,
#             "latitude": 35.8652,
#             "local_site_name": "Triple Oak",
#             "longitude": -78.8197,
#             "method": "Teledyne-API Model 200EUP or T200UP - Photolytic-Chemiluminescence",
#             "metric_used": "Daily Maximum 1-hour average",
#             "ninetieth_percentile": 26.2,
#             "ninety_eighth_percentile": 33.1,
#             "ninety_fifth_percentile": 29.1,
#             "ninety_ninth_percentile": 33.8,
#             "null_observation_count": 794,
#             "observation_count": 7942,
#             "observation_percent": 91.0,
#             "parameter": "Nitrogen dioxide (NO2)",
#             "parameter_code": "42602",
#             "poc": 1,
#             "pollutant_standard": "NO2 1-hour",
#             "primary_exceedance_count": 0,
#             "required_day_count": 365,
#             "sample_duration": "1 HOUR",
#             "second_max_datetime": "2018-03-09 22:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 34.3,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 21.1,
#             "site_address": "2826 TRIPLE OAK DRIVE",
#             "site_number": "0021",
#             "standard_deviation": 6.860599,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 8.0,
#             "third_max_datetime": "2018-04-06 20:00",
#             "third_max_value": 33.9,
#             "units_of_measure": "Parts per billion",
#             "valid_day_count": 343,
#             "validity_indicator": "Y",
#             "year": 2018
#         }
#     ],
#     "Header": [
#         {
#             "request_time": "2020-04-25T14:45:19-04:00",
#             "rows": 12,
#             "status": "Success",
#             "url": "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=42602&bdate=20180101&edate=20181231&state=37"
#         }
#     ]
# }
