# %%
import requests
import json

# %%
url = "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=45201&bdate=20110101&edate=20111231&state=37"

# %%
response = requests.get(url)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# {
#     "Data": [
#         {
#             "arithmetic_mean": 1.362162,
#             "cbsa": "Asheville, NC",
#             "cbsa_code": "11700",
#             "certification_indicator": "Certification not required",
#             "city": "Asheville",
#             "county": "Buncombe",
#             "county_code": "021",
#             "date_of_last_change": "2017-09-06",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.3,
#             "first_max_datetime": "2011-06-20 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 3.8,
#             "fourth_max_datetime": "2011-01-15 00:00",
#             "fourth_max_value": 2.0,
#             "latitude": 35.57222,
#             "local_site_name": "AB Tech",
#             "longitude": -82.55889,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 2.0,
#             "ninety_eighth_percentile": 3.8,
#             "ninety_fifth_percentile": 2.4,
#             "ninety_ninth_percentile": 3.8,
#             "null_observation_count": 24,
#             "observation_count": 37,
#             "observation_percent": 61.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 1,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 61,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-12-29 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 2.4,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.5,
#             "site_address": "AB TECH COLLEGE",
#             "site_number": "0035",
#             "standard_deviation": 0.579919,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.8,
#             "third_max_datetime": "2011-12-11 00:00",
#             "third_max_value": 2.1,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 37,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.1,
#             "cbsa": null,
#             "cbsa_code": null,
#             "certification_indicator": "Certification not required",
#             "city": "Candor",
#             "county": "Montgomery",
#             "county_code": "123",
#             "date_of_last_change": "2012-02-29",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.1,
#             "first_max_datetime": "2011-12-11 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 1.7,
#             "fourth_max_datetime": "2011-12-23 00:00",
#             "fourth_max_value": 0.5,
#             "latitude": 35.263165,
#             "local_site_name": "Candor: EPA CASTNet Site",
#             "longitude": -79.836636,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 1.7,
#             "ninety_eighth_percentile": 1.7,
#             "ninety_fifth_percentile": 1.7,
#             "ninety_ninth_percentile": 1.7,
#             "null_observation_count": 1,
#             "observation_count": 4,
#             "observation_percent": 80.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 2,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 5,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-12-05 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 1.1,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.7,
#             "site_address": "126 PERRY DRIVE",
#             "site_number": "0001",
#             "standard_deviation": 0.489898,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.5,
#             "third_max_datetime": "2011-12-17 00:00",
#             "third_max_value": 1.1,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 4,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 2.253125,
#             "cbsa": null,
#             "cbsa_code": null,
#             "certification_indicator": "Certification not required",
#             "city": "Candor",
#             "county": "Montgomery",
#             "county_code": "123",
#             "date_of_last_change": "2017-09-06",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 2.1,
#             "first_max_datetime": "2011-07-14 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 6.0,
#             "fourth_max_datetime": "2011-09-18 00:00",
#             "fourth_max_value": 4.5,
#             "latitude": 35.263165,
#             "local_site_name": "Candor: EPA CASTNet Site",
#             "longitude": -79.836636,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 4.5,
#             "ninety_eighth_percentile": 6.0,
#             "ninety_fifth_percentile": 4.7,
#             "ninety_ninth_percentile": 6.0,
#             "null_observation_count": 29,
#             "observation_count": 32,
#             "observation_percent": 52.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 1,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 61,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-08-31 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 4.7,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 3.3,
#             "site_address": "126 PERRY DRIVE",
#             "site_number": "0001",
#             "standard_deviation": 1.533704,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.6,
#             "third_max_datetime": "2011-08-07 00:00",
#             "third_max_value": 4.5,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 32,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.93871,
#             "cbsa": "Charlotte-Concord-Gastonia, NC-SC",
#             "cbsa_code": "16740",
#             "certification_indicator": "Certification not required",
#             "city": "Charlotte",
#             "county": "Mecklenburg",
#             "county_code": "119",
#             "date_of_last_change": "2012-02-28",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.7,
#             "first_max_datetime": "2011-07-20 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 5.3,
#             "fourth_max_datetime": "2011-07-02 00:00",
#             "fourth_max_value": 3.3,
#             "latitude": 35.2401,
#             "local_site_name": "Garinger High School",
#             "longitude": -80.785683,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 3.3,
#             "ninety_eighth_percentile": 5.3,
#             "ninety_fifth_percentile": 3.7,
#             "ninety_ninth_percentile": 5.3,
#             "null_observation_count": 30,
#             "observation_count": 31,
#             "observation_percent": 51.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 2,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 61,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-07-08 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 3.7,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 2.7,
#             "site_address": "1130 EASTWAY DRIVE",
#             "site_number": "0041",
#             "standard_deviation": 1.114055,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.8,
#             "third_max_datetime": "2011-12-29 00:00",
#             "third_max_value": 3.4,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 31,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.04,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certification not required",
#             "city": "Raleigh",
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2012-02-29",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.9,
#             "first_max_datetime": "2011-10-24 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 1.9,
#             "fourth_max_datetime": "2011-10-18 00:00",
#             "fourth_max_value": 1.4,
#             "latitude": 35.856111,
#             "local_site_name": "Millbrook School",
#             "longitude": -78.574167,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 1.9,
#             "ninety_eighth_percentile": 1.9,
#             "ninety_fifth_percentile": 1.9,
#             "ninety_ninth_percentile": 1.9,
#             "null_observation_count": 0,
#             "observation_count": 10,
#             "observation_percent": 100.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 8,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 10,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-10-30 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 1.6,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.5,
#             "site_address": "3801 SPRING FOREST RD.",
#             "site_number": "0014",
#             "standard_deviation": 0.514674,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.6,
#             "third_max_datetime": "2011-10-06 00:00",
#             "third_max_value": 1.5,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 10,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.312903,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certification not required",
#             "city": "Raleigh",
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2013-11-01",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.2,
#             "first_max_datetime": "2011-05-21 05:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 3.1,
#             "fourth_max_datetime": "2011-07-02 05:00",
#             "fourth_max_value": 1.9,
#             "latitude": 35.856111,
#             "local_site_name": "Millbrook School",
#             "longitude": -78.574167,
#             "method": "6L PRESSURIZED CANISTER - PE8700;AUTO GC;SUBAMBIENT-DUAL FID",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 1.9,
#             "ninety_eighth_percentile": 3.1,
#             "ninety_fifth_percentile": 2.8,
#             "ninety_ninth_percentile": 3.1,
#             "null_observation_count": 2,
#             "observation_count": 31,
#             "observation_percent": 26.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 2,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 121,
#             "sample_duration": "3 HOURS",
#             "second_max_datetime": "2011-04-03 05:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 2.8,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.7,
#             "site_address": "3801 SPRING FOREST RD.",
#             "site_number": "0014",
#             "standard_deviation": 0.609777,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.8,
#             "third_max_datetime": "2011-08-13 05:00",
#             "third_max_value": 2.1,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 0,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.456757,
#             "cbsa": "Raleigh, NC",
#             "cbsa_code": "39580",
#             "certification_indicator": "Certification not required",
#             "city": "Raleigh",
#             "county": "Wake",
#             "county_code": "183",
#             "date_of_last_change": "2017-09-06",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.1,
#             "first_max_datetime": "2011-09-30 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 4.4,
#             "fourth_max_datetime": "2011-12-29 00:00",
#             "fourth_max_value": 2.7,
#             "latitude": 35.856111,
#             "local_site_name": "Millbrook School",
#             "longitude": -78.574167,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 2.7,
#             "ninety_eighth_percentile": 4.4,
#             "ninety_fifth_percentile": 4.0,
#             "ninety_ninth_percentile": 4.4,
#             "null_observation_count": 24,
#             "observation_count": 37,
#             "observation_percent": 61.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 1,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 61,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-07-08 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 4.0,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 2.0,
#             "site_address": "3801 SPRING FOREST RD.",
#             "site_number": "0014",
#             "standard_deviation": 0.950012,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.6,
#             "third_max_datetime": "2011-08-13 00:00",
#             "third_max_value": 2.8,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 37,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.261905,
#             "cbsa": "Charlotte-Concord-Gastonia, NC-SC",
#             "cbsa_code": "16740",
#             "certification_indicator": "Certification not required",
#             "city": "Rockwell",
#             "county": "Rowan",
#             "county_code": "159",
#             "date_of_last_change": "2013-11-05",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.1,
#             "first_max_datetime": "2011-07-11 05:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 4.2,
#             "fourth_max_datetime": "2011-03-04 06:00",
#             "fourth_max_value": 2.5,
#             "latitude": 35.551868,
#             "local_site_name": "Rockwell",
#             "longitude": -80.395039,
#             "method": "6L PRESSURIZED CANISTER - PE8700;AUTO GC;SUBAMBIENT-DUAL FID",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 2.1,
#             "ninety_eighth_percentile": 3.4,
#             "ninety_fifth_percentile": 2.5,
#             "ninety_ninth_percentile": 4.2,
#             "null_observation_count": 14,
#             "observation_count": 63,
#             "observation_percent": 52.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 1,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 121,
#             "sample_duration": "3 HOURS",
#             "second_max_datetime": "2011-06-17 05:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 3.4,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.4,
#             "site_address": "301 WEST ST & GOLD HILL AVENUE",
#             "site_number": "0021",
#             "standard_deviation": 0.717169,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.6,
#             "third_max_datetime": "2011-01-15 06:00",
#             "third_max_value": 3.1,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 0,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 0.733333,
#             "cbsa": "Wilmington, NC",
#             "cbsa_code": "48900",
#             "certification_indicator": "Certification not required",
#             "city": "Wilmington",
#             "county": "New Hanover",
#             "county_code": "129",
#             "date_of_last_change": "2017-09-06",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.6,
#             "first_max_datetime": "2011-01-15 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 2.3,
#             "fourth_max_datetime": "2011-01-09 00:00",
#             "fourth_max_value": 0.7,
#             "latitude": 34.23583,
#             "local_site_name": "Eagles Island",
#             "longitude": -77.9547,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 2.3,
#             "ninety_eighth_percentile": 2.3,
#             "ninety_fifth_percentile": 2.3,
#             "ninety_ninth_percentile": 2.3,
#             "null_observation_count": 37,
#             "observation_count": 9,
#             "observation_percent": 20.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 2,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 46,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-01-27 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 1.1,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 0.8,
#             "site_address": "#1 Battleship Road",
#             "site_number": "0010",
#             "standard_deviation": 0.67082,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.0,
#             "third_max_datetime": "2011-01-21 00:00",
#             "third_max_value": 0.8,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 9,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 1.033333,
#             "cbsa": "Wilmington, NC",
#             "cbsa_code": "48900",
#             "certification_indicator": "Certification not required",
#             "city": "Wilmington",
#             "county": "New Hanover",
#             "county_code": "129",
#             "date_of_last_change": "2017-09-06",
#             "datum": "NAD83",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 0.8,
#             "first_max_datetime": "2011-07-26 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 6.3,
#             "fourth_max_datetime": "2011-07-02 00:00",
#             "fourth_max_value": 1.7,
#             "latitude": 34.23583,
#             "local_site_name": "Eagles Island",
#             "longitude": -77.9547,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 1.7,
#             "ninety_eighth_percentile": 6.3,
#             "ninety_fifth_percentile": 1.8,
#             "ninety_ninth_percentile": 6.3,
#             "null_observation_count": 25,
#             "observation_count": 36,
#             "observation_percent": 59.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 1,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 61,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-08-13 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 1.8,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 1.1,
#             "site_address": "#1 Battleship Road",
#             "site_number": "0010",
#             "standard_deviation": 0.982998,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.4,
#             "third_max_datetime": "2011-01-15 00:00",
#             "third_max_value": 1.7,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 36,
#             "validity_indicator": "N",
#             "year": 2011
#         },
#         {
#             "arithmetic_mean": 3.3,
#             "cbsa": "Winston-Salem, NC",
#             "cbsa_code": "49180",
#             "certification_indicator": "Certification not required",
#             "city": "Winston-Salem",
#             "county": "Forsyth",
#             "county_code": "067",
#             "date_of_last_change": "2012-02-29",
#             "datum": "WGS84",
#             "event_type": "No Events",
#             "exceptional_data_count": 0,
#             "fiftieth_percentile": 1.5,
#             "first_max_datetime": "2011-08-19 00:00",
#             "first_max_n_o_datetime": null,
#             "first_max_nonoverlap_value": null,
#             "first_max_value": 8.7,
#             "fourth_max_datetime": "2011-07-14 00:00",
#             "fourth_max_value": 8.1,
#             "latitude": 36.110693,
#             "local_site_name": "Hattie Avenue",
#             "longitude": -80.226438,
#             "method": "SS 6L- PRESSURIZED CANISTER - CRYOGENIC PRECON: GC/MS",
#             "metric_used": "Observed Values",
#             "ninetieth_percentile": 8.1,
#             "ninety_eighth_percentile": 8.7,
#             "ninety_fifth_percentile": 8.6,
#             "ninety_ninth_percentile": 8.7,
#             "null_observation_count": 25,
#             "observation_count": 36,
#             "observation_percent": 59.0,
#             "parameter": "Benzene",
#             "parameter_code": "45201",
#             "poc": 2,
#             "pollutant_standard": null,
#             "primary_exceedance_count": null,
#             "required_day_count": 61,
#             "sample_duration": "24 HOUR",
#             "second_max_datetime": "2011-08-25 00:00",
#             "second_max_n_o_datetime": null,
#             "second_max_nonoverlap_value": null,
#             "second_max_value": 8.6,
#             "secondary_exceedance_count": null,
#             "seventy_fifth_percentile": 6.6,
#             "site_address": "1300 BLK. HATTIE AVENUE",
#             "site_number": "0022",
#             "standard_deviation": 2.973502,
#             "state": "North Carolina",
#             "state_code": "37",
#             "tenth_percentile": 0.8,
#             "third_max_datetime": "2011-08-31 00:00",
#             "third_max_value": 8.6,
#             "units_of_measure": "Parts per billion Carbon",
#             "valid_day_count": 36,
#             "validity_indicator": "N",
#             "year": 2011
#         }
#     ],
#     "Header": [
#         {
#             "request_time": "2020-04-25T12:58:27-04:00",
#             "rows": 11,
#             "status": "Success",
#             "url": "https://aqs.epa.gov/data/api/annualData/byState?email=lilu216@hotmail.com&key=baygoose48&param=45201&bdate=20110101&edate=20111231&state=37"
#         }
#     ]
# }
